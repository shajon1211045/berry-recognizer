# %% [markdown]
# # Setting up necessary things

# %%
# !pip install -Uqq fastai

# %%
from fastai.vision.all import *

# %%
cd "D:\\berry_recogniser"
# Out:
# D:\berry_recogniser

# %%
img_path = f"D:\\berry_recogniser\\Test images"
model_path = f"D:\\berry_Type_recognizer\\models\\berry-recognizer-v2.pkl"

# %% [markdown]
# # Load the trained Model

# %%
model = load_learner(model_path)

# %%
model.export('berry-recognizer-v2-portable.pkl')

# %%
import os
print(os.getcwd())
# Out:
# d:\berry\notebooks

# %% [markdown]
# # Inference 1
#
# Target = Blueberry

# %%
img = Image.open(f'{img_path}/test_image_01.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x81>

# %%
model.predict(f'{img_path}/test_image_01.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Blueberry',
#  tensor(0),
#  tensor([9.9693e-01, 1.8125e-04, 6.7477e-05, 1.6911e-03, 5.1317e-06, 1.7057e-05,
#          1.1979e-05, 3.0637e-05, 1.0385e-03, 2.3568e-05]))

# %% [markdown]
# # Inference 2
# Target = Raspberry

# %%
img = Image.open(f'{img_path}/test_image_02.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x85>

# %%
model.predict(f'{img_path}/test_image_02.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00&lt;?]
#     </div>
# ('Currants',
#  tensor(2),
#  tensor([0.0099, 0.1413, 0.3445, 0.0006, 0.0014, 0.0057, 0.2402, 0.0029, 0.2513,
#          0.0023]))

# %% [markdown]
# # Inference 3
# Target = Mulberry

# %%
img = Image.open(f'{img_path}/test_image_03.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x85>

# %%
model.predict(f'{img_path}/test_image_03.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Mulberry',
#  tensor(7),
#  tensor([3.4370e-08, 1.8258e-08, 2.4804e-10, 1.2932e-05, 1.5569e-09, 2.0362e-07,
#          6.2601e-09, 9.9999e-01, 8.1175e-07, 1.3216e-08]))

# %% [markdown]
# # Inference 4
#
# Target = Cranberry

# %%
img = Image.open(f'{img_path}/test_image_04.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x96>

# %%
model.predict(f'{img_path}/test_image_04.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Cranberry',
#  tensor(1),
#  tensor([3.8612e-02, 7.9867e-01, 5.8581e-02, 8.5344e-02, 5.1860e-03, 3.5116e-04,
#          2.1138e-03, 4.7154e-04, 9.4440e-03, 1.2236e-03]))

# %% [markdown]
# # Inference 5
#
# Target = Strawberry

# %%
img = Image.open(f'{img_path}/test_image_05.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x82>

# %%
model.predict(f'{img_path}/test_image_05.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Strawberry',
#  tensor(9),
#  tensor([1.8415e-09, 1.1360e-08, 1.3902e-10, 1.1900e-09, 3.1650e-09, 3.6874e-08,
#          1.6653e-07, 2.0024e-06, 1.3135e-06, 1.0000e+00]))
